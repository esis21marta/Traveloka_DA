# %%
import pandas as pd
from matplotlib import pyplot
from pylab import rcParams
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import itertools
from datetime import datetime
import seaborn as sns
import numpy as np
from optbinning import OptimalBinning

# %%
df_trave = pd.read_csv('df_traveloka_03032022.csv')
display(df_trave.info())
print('Data Structure Trave Retention Historical')
display(df_trave.shape)
display(df_trave.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206007 entries, 0 to 206006
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   primary_sales_product_type           206007 non-null  object
#  1   is_churn                             206007 non-null  int64
#  2   diff_last_issued_booking_time_hours  206007 non-null  float64
#  3   avg_issued_invoice_amount_idr        206007 non-null  float64
#  4   pct_succes_trx                       206007 non-null  float64
#  5   profile_id                           206007 non-null  int64
#  6   avg_booking_invoice_amount_idr       206007 non-null  float64
#  7   count_issued                         206007 non-null  int64
#  8   tenure_hours                         206007 non-null  float64
#  9   invoice_per_count_issued             206007 non-null  float64
# ...

# %%
display(df_trave.cluster.value_counts(dropna=False))
df_retention_trave = df_trave.copy()
df_retention_trave.head()
# Out:
# 0    143340
# 1     62667
# Name: cluster, dtype: int64
#   primary_sales_product_type  is_churn  diff_last_issued_booking_time_hours  \
# 0                      HOTEL         0                                 0.16
# 1                     FLIGHT         0                                 0.10
# 2                      TRAIN         0                                 0.56
# 3                      HOTEL         0                                 0.34
# 4                     FLIGHT         0                              1075.64
#
#    avg_issued_invoice_amount_idr  pct_succes_trx  profile_id  \
# 0                   1.193237e+06        0.562500     3632279
# 1                   1.031982e+06        0.568966     3632279
# 2                   2.527762e+05        0.387097    17407638
# 3                   5.875060e+05        0.611111    17407638
# 4                   1.443118e+06        0.377358     4618047
#
#    avg_booking_invoice_amount_idr  count_issued  tenure_hours  \
# ...

# %%
dfopt = df_retention_trave.copy()
dfopt.head()
# Out:
#   primary_sales_product_type  is_churn  diff_last_issued_booking_time_hours  \
# 0                      HOTEL         0                                 0.16
# 1                     FLIGHT         0                                 0.10
# 2                      TRAIN         0                                 0.56
# 3                      HOTEL         0                                 0.34
# 4                     FLIGHT         0                              1075.64
#
#    avg_issued_invoice_amount_idr  pct_succes_trx  profile_id  \
# 0                   1.193237e+06        0.562500     3632279
# 1                   1.031982e+06        0.568966     3632279
# 2                   2.527762e+05        0.387097    17407638
# 3                   5.875060e+05        0.611111    17407638
# 4                   1.443118e+06        0.377358     4618047
#
#    avg_booking_invoice_amount_idr  count_issued  tenure_hours  \
# 0                    2.000823e+06            18  28337.007566
# ...

# %% [markdown]
# #### 1. count_issued

# %%
#count_issued
optb = OptimalBinning(name='count_issued', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['count_issued'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [ 1.5  2.5  3.5  5.5  8.5 17.5]
#                   Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0        (-inf, 1.50)   74485   0.361565      34266  40219    0.539961
# 1        [1.50, 2.50)   33629   0.163242      18135  15494    0.460733
# 2        [2.50, 3.50)   19184   0.093123      11654   7530    0.392515
# 3        [3.50, 5.50)   22321   0.108351      14834   7487    0.335424
# 4        [5.50, 8.50)   17603   0.085449      12841   4762    0.270522
# 5       [8.50, 17.50)   20728   0.100618      16508   4220    0.203589
# 6        [17.50, inf)   18057   0.087652      15966   2091    0.115800
# 7             Special       0   0.000000          0      0    0.000000
# 8             Missing       0   0.000000          0      0    0.000000
# Totals                 206007   1.000000     124204  81803    0.397088
#
#              WoE        IV        JS
# 0      -0.577797  0.124672  0.015371
# 1      -0.260221  0.011293  0.001408
# ...

# %% [markdown]
# #### 2. invoice_per_count_booking

# %%
#invoice_per_count_booking
optb = OptimalBinning(name='invoice_per_count_booking', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['invoice_per_count_booking'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [ 11922.5859375   24750.97753906  37861.24609375  49089.9765625
#   72219.68359375  88573.75390625 108706.9609375  134813.875
#  165405.9375     210600.4765625  307076.5        390731.703125
#  512066.796875  ]
#                            Bin   Count  Count (%)  Non-event  Event  \
# 0             (-inf, 11922.59)   11112   0.053940       9759   1353
# 1         [11922.59, 24750.98)   16331   0.079274      12961   3370
# 2         [24750.98, 37861.25)   14508   0.070425      10593   3915
# 3         [37861.25, 49089.98)   10658   0.051736       7427   3231
# 4         [49089.98, 72219.68)   17919   0.086982      11855   6064
# 5         [72219.68, 88573.75)   10336   0.050173       6358   3978
# 6        [88573.75, 108706.96)   10644   0.051668       6429   4215
# 7       [108706.96, 134813.88)   11488   0.055765       6693   4795
# 8       [134813.88, 165405.94)   10784   0.052348       6135   4649
# ...

# %% [markdown]
# #### 3. count_booking

# %%
#count_booking
optb = OptimalBinning(name='count_booking', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['count_booking'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [ 1.5  2.5  3.5  4.5  5.5  7.5  9.5 12.5 16.5 27.5 47.5]
#                    Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0         (-inf, 1.50)   33880   0.164460      15867  18013    0.531671
# 1         [1.50, 2.50)   25446   0.123520      12222  13224    0.519689
# 2         [2.50, 3.50)   19268   0.093531       9934   9334    0.484430
# 3         [3.50, 4.50)   14840   0.072036       7941   6899    0.464892
# 4         [4.50, 5.50)   11798   0.057270       6653   5145    0.436091
# 5         [5.50, 7.50)   17791   0.086361      10431   7360    0.413692
# 6         [7.50, 9.50)   13097   0.063576       8224   4873    0.372070
# 7        [9.50, 12.50)   13901   0.067478       9117   4784    0.344148
# 8       [12.50, 16.50)   12418   0.060280       8632   3786    0.304880
# 9       [16.50, 27.50)   18542   0.090007      13904   4638    0.250135
# 10      [27.50, 47.50)   13096   0.063571      10743   2353    0.179673
# ...

# %% [markdown]
# #### 4. pct_succes_trx

# %%
#pct_succes_trx
optb = OptimalBinning(name='pct_succes_trx', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['pct_succes_trx'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [0.20050251 0.33395292 0.50113124 0.66705975 0.75040984 0.99456522]
#                  Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0       (-inf, 0.20)   19391   0.094128      10501   8890    0.458460
# 1       [0.20, 0.33)   31494   0.152878      17843  13651    0.433448
# 2       [0.33, 0.50)   46164   0.224089      27659  18505    0.400853
# 3       [0.50, 0.67)   29789   0.144602      20818   8971    0.301151
# 4       [0.67, 0.75)   11846   0.057503       8698   3148    0.265744
# 5       [0.75, 0.99)   15565   0.075556      12249   3316    0.213042
# 6        [0.99, inf)   51758   0.251244      26436  25322    0.489238
# 7            Special       0   0.000000          0      0    0.000000
# 8            Missing       0   0.000000          0      0    0.000000
# Totals                206007   1.000000     124204  81803    0.397088
#
#              WoE        IV        JS
# 0      -0.251068  0.006058  0.000755
# ...

# %% [markdown]
# #### 5. avg_booking_invoice_amount_idr

# %%
#avg_booking_invoice_amount_idr
optb = OptimalBinning(name='avg_booking_invoice_amount_idr', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['avg_booking_invoice_amount_idr'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [ 210794.75      301288.        367534.671875  433266.046875
#   504955.5       587234.4375    672920.75      770886.625
#   894425.125     999561.75     1307363.75     1498896.      ]
#                              Bin   Count  Count (%)  Non-event  Event  \
# 0              (-inf, 210794.75)   16103   0.078167      11196   4907
# 1         [210794.75, 301288.00)   13617   0.066100       8820   4797
# 2         [301288.00, 367534.67)   10944   0.053124       6551   4393
# 3         [367534.67, 433266.05)   10620   0.051552       6111   4509
# 4         [433266.05, 504955.50)   11268   0.054697       6316   4952
# 5         [504955.50, 587234.44)   12312   0.059765       6717   5595
# 6         [587234.44, 672920.75)   11846   0.057503       6660   5186
# 7         [672920.75, 770886.62)   12842   0.062338       7283   5559
# 8         [770886.62, 894425.12)   14558   0.070668       8484   6074
# 9         [894425.12, 999561.75)   11138   0.054066       6627   4511
# ...

# %% [markdown]
# #### 6. diff_last_issued_booking_time_hours

# %%
#diff_last_issued_booking_time_hours
optb = OptimalBinning(name='diff_last_issued_booking_time_hours', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['diff_last_issued_booking_time_hours'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [3.49999992e-02 5.49999997e-02 7.49999993e-02 9.50000025e-02
#  1.34999998e-01 1.85000002e-01 4.77391504e+03]
#                     Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0          (-inf, 0.03)   10831   0.052576       8330   2501    0.230911
# 1          [0.03, 0.05)   17351   0.084225      12718   4633    0.267016
# 2          [0.05, 0.07)   18123   0.087973      12429   5694    0.314186
# 3          [0.07, 0.10)   15279   0.074167      10150   5129    0.335690
# 4          [0.10, 0.13)   20912   0.101511      13164   7748    0.370505
# 5          [0.13, 0.19)   16059   0.077954       9501   6558    0.408369
# 6       [0.19, 4773.92)   97151   0.471591      56025  41126    0.423320
# 7        [4773.92, inf)   10301   0.050003       1887   8414    0.816814
# 8               Special       0   0.000000          0      0    0.000000
# 9               Missing       0   0.000000          0      0    0.000000
# ...

# %% [markdown]
# #### 7. diff_last_first_issued_time_days

# %%
#diff_last_first_issued_time_days
optb = OptimalBinning(name='diff_last_first_issued_time_days', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['diff_last_first_issued_time_days'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [   1.18756467   14.90961218   62.51024437  157.91420746  238.15359497
#   390.07376099  518.48294067 1020.92886353]
#                       Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0            (-inf, 1.19)   81279   0.394545      37354  43925    0.540422
# 1           [1.19, 14.91)   10315   0.050071       5043   5272    0.511100
# 2          [14.91, 62.51)   12528   0.060813       6330   6198    0.494732
# 3         [62.51, 157.91)   16494   0.080065       9295   7199    0.436462
# 4        [157.91, 238.15)   12039   0.058440       7506   4533    0.376526
# 5        [238.15, 390.07)   19038   0.092414      13592   5446    0.286059
# 6        [390.07, 518.48)   13066   0.063425      10242   2824    0.216133
# 7       [518.48, 1020.93)   28384   0.137782      22907   5477    0.192961
# 8          [1020.93, inf)   12864   0.062444      11935    929    0.072217
# 9                 Special       0   0.000000          0      0    0.000000
# ...

# %% [markdown]
# #### 8. avg_issued_invoice_amount_idr

# %%
#avg_issued_invoice_amount_idr
optb = OptimalBinning(name='avg_issued_invoice_amount_idr', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['avg_issued_invoice_amount_idr'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [ 188003.4921875  260824.         336967.78125    395568.171875
#   469692.5625     546463.84375    705779.8125     849157.40625
#   955094.90625   1099840.1875   ]
#                             Bin   Count  Count (%)  Non-event  Event  \
# 0             (-inf, 188003.49)   14541   0.070585      10014   4527
# 1        [188003.49, 260824.00)   11008   0.053435       7194   3814
# 2        [260824.00, 336967.78)   13280   0.064464       8215   5065
# 3        [336967.78, 395568.17)   10471   0.050828       5997   4474
# 4        [395568.17, 469692.56)   12215   0.059294       6854   5361
# 5        [469692.56, 546463.84)   12228   0.059357       6691   5537
# 6        [546463.84, 705779.81)   23022   0.111753      12926  10096
# 7        [705779.81, 849157.41)   17548   0.085182      10212   7336
# 8        [849157.41, 955094.91)   11509   0.055867       6886   4623
# 9       [955094.91, 1099840.19)   13678   0.066396       8343   5335
# ...

# %% [markdown]
# #### 9. invoice_per_count_issued

# %%
#invoice_per_count_issued
optb = OptimalBinning(name='invoice_per_count_issued', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['invoice_per_count_issued'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [ 24994.96484375  41653.02148438  68428.05078125 110447.8125
#  160333.03125    211070.0859375  260403.25       317137.515625
#  390774.796875   524922.75      ]
#                            Bin   Count  Count (%)  Non-event  Event  \
# 0             (-inf, 24994.96)   11528   0.055959      10410   1118
# 1         [24994.96, 41653.02)   10309   0.050042       8572   1737
# 2         [41653.02, 68428.05)   15131   0.073449      11762   3369
# 3        [68428.05, 110447.81)   20282   0.098453      14396   5886
# 4       [110447.81, 160333.03)   18669   0.090623      12194   6475
# 5       [160333.03, 211070.09)   15024   0.072930       9177   5847
# 6       [211070.09, 260403.25)   12431   0.060343       7100   5331
# 7       [260403.25, 317137.52)   11824   0.057396       6486   5338
# 8       [317137.52, 390774.80)   12782   0.062046       6497   6285
# 9       [390774.80, 524922.75)   16977   0.082410       8264   8713
# ...

# %% [markdown]
# #### 10. tenure_hours

# %%
#tenure_hours
optb = OptimalBinning(name='tenure_hours', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['tenure_hours'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [  106.99559402   768.73907471  2204.93713379  3790.53918457
#   5737.80737305  9313.74511719 11997.57910156 24650.60839844]
#                          Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0             (-inf, 107.00)   70868   0.344008      31859  39009    0.550446
# 1           [107.00, 768.74)   13946   0.067697       6472   7474    0.535924
# 2          [768.74, 2204.94)   13542   0.065736       6737   6805    0.502511
# 3         [2204.94, 3790.54)   11696   0.056775       6381   5315    0.454429
# 4         [3790.54, 5737.81)   13043   0.063313       7801   5242    0.401901
# 5         [5737.81, 9313.75)   20281   0.098448      14064   6217    0.306543
# 6        [9313.75, 11997.58)   12705   0.061673       9755   2950    0.232192
# 7       [11997.58, 24650.61)   34002   0.165053      26610   7392    0.217399
# 8            [24650.61, inf)   15924   0.077298      14525   1399    0.087855
# ...

# %% [markdown]
# #### 11. diff_last_first_booking_time_days

# %%
#diff_last_first_booking_time_days
optb = OptimalBinning(name='diff_last_first_booking_time_days', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['diff_last_first_booking_time_days'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [1.02275133e+00 8.35938358e+00 3.47302113e+01 9.18764381e+01
#  1.57934204e+02 2.60040085e+02 3.90173218e+02 4.98582336e+02
#  8.62292450e+02 1.09804688e+03]
#                       Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0            (-inf, 1.02)   54599   0.265035      25593  29006    0.531255
# 1            [1.02, 8.36)   10697   0.051925       5161   5536    0.517528
# 2           [8.36, 34.73)   10744   0.052154       5225   5519    0.513682
# 3          [34.73, 91.88)   13052   0.063357       6778   6274    0.480693
# 4         [91.88, 157.93)   12286   0.059639       6718   5568    0.453199
# 5        [157.93, 260.04)   17145   0.083225      10178   6967    0.406358
# 6        [260.04, 390.17)   18917   0.091827      12378   6539    0.345668
# 7        [390.17, 498.58)   13482   0.065444       9599   3883    0.288014
# 8        [498.58, 862.29)   29686   0.144102      21840   7846    0.264300
# ...

# %% [markdown]
# #### 12. cluster

# %%
#cluster
optb = OptimalBinning(name='cluster', dtype="numerical", solver="cp")
data = dfopt.copy()
x = data['cluster'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [0.5]
#                  Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0       (-inf, 0.50)  143340   0.695802      73613  69727    0.486445
# 1        [0.50, inf)   62667   0.304198      50591  12076    0.192701
# 2            Special       0   0.000000          0      0    0.000000
# 3            Missing       0   0.000000          0      0    0.000000
# Totals                206007   1.000000     124204  81803    0.397088
#
#              WoE        IV        JS
# 0      -0.363377  0.094369  0.011732
# 1       1.014942  0.263579  0.031602
# 2            0.0  0.000000  0.000000
# 3            0.0  0.000000  0.000000
# Totals            0.357948  0.043334
# None

# %% [markdown]
# #### 13. primary_sales_product_type

# %%
#primary_sales_product_type
optb = OptimalBinning(name='primary_sales_product_type', dtype="categorical", solver="cp")
data = dfopt.copy()
x = data['primary_sales_product_type'].values
y = data['is_churn']
optb.fit(x, y)
result = optb.splits
print("Optimal Splits : ", result)
display(optb.binning_table.build())
display(optb.binning_table.plot(metric="woe"))
# Out:
# Optimal Splits :  [array(['TRAIN', 'TRIP'], dtype=object), array(['HOTEL'], dtype=object), array(['FLIGHT'], dtype=object)]
#                   Bin   Count  Count (%)  Non-event  Event  Event rate  \
# 0       [TRAIN, TRIP]   36355   0.176475      26286  10069    0.276963
# 1             [HOTEL]   66028   0.320513      40347  25681    0.388941
# 2            [FLIGHT]  103624   0.503012      57571  46053    0.444424
# 3             Special       0   0.000000          0      0    0.000000
# 4             Missing       0   0.000000          0      0    0.000000
# Totals                 206007   1.000000     124204  81803    0.397088
#
#              WoE        IV        JS
# 0       0.541964  0.047989  0.005926
# 1       0.034154  0.000373  0.000047
# 2      -0.194385  0.019333  0.002413
# 3            0.0  0.000000  0.000000
# 4            0.0  0.000000  0.000000
# Totals            0.067695  0.008386
# None

# %% [markdown]
# # Finish
